# %% [markdown]
# <a href="https://colab.research.google.com/github/uniqueraj/rajendra/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name: Rajendra Budha**
#  **'Practice Makes Perfect** ❤
#
# ---
#
# \

# %% [markdown]
# **install**

# %%
# install modules
# !pip install pandas
# !pip install numpy
# !pip install matplotlib

# %% [markdown]
# **Imports Libraries**

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Import Daata**

# %%
# Import Data
df = pd.read_csv('https://raw.githubusercontent.com/jsdhami/Python-For-Research/main/Data/hourly_ktm_weather_data.csv')

df = pd.DataFrame({'date':df['date'], 'temp':df['temperature_2m'], 'ppt':df['precipitation'], 'windspeed':df['wind_speed_10m']})
df.head()
print(len(df))
# Out:
# 39029

# %%
df = df.tail(25)
df.head()
# print all
print(df.to_string())
# Out:
#                             date    temp  ppt  windspeed
# 39004  2024-06-12 22:15:00+00:00  20.064  0.0   1.080000
# 39005  2024-06-12 23:15:00+00:00  19.964  0.0   3.671294
# 39006  2024-06-13 00:15:00+00:00  22.914  0.0   3.075841
# 39007  2024-06-13 01:15:00+00:00  24.264  0.0   2.099143
# 39008  2024-06-13 02:15:00+00:00  25.664  0.0   3.758510
# 39009  2024-06-13 03:15:00+00:00  27.114  0.1   6.489992
# 39010  2024-06-13 04:15:00+00:00  28.264  0.1   7.200000
# 39011  2024-06-13 05:15:00+00:00  29.264  0.1   8.707237
# 39012  2024-06-13 06:15:00+00:00  29.564  0.3   9.028754
# 39013  2024-06-13 07:15:00+00:00  29.764  0.6   9.028754
# 39014  2024-06-13 08:15:00+00:00  29.164  0.4   8.049845
# 39015  2024-06-13 09:15:00+00:00  28.064  0.5   7.594208
# 39016  2024-06-13 10:15:00+00:00  26.414  0.2   4.198285
# 39017  2024-06-13 11:15:00+00:00  25.964  0.1   4.104631
# 39018  2024-06-13 12:15:00+00:00  24.614  0.1   4.198285
# ...

# %% [markdown]
# **Creating Data**

# %%
x=df['date']
y=df['temp']
z=df['ppt']
w=df['windspeed']

# %% [markdown]
# **1. Line Ploting**

# %%
#Line Ploting
# Creating Fig.
fig, ax = plt.subplots(figsize=(15, 5))

ax.plot(x, y,  label='Temperature', color='red')
ax.plot(x, z, label='precipitation', color='yellow')
ax.plot(x, w, label='wind speed', color='blue')

#label
ax.set_ylabel('Temperature,Precipitation,Wind Speed', color='violet')
ax.set_xlabel('Date')
ax.set_title('Weather Data  Of KTM 2024', color='orange')

# Set tick/Tick Label
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85, color='yellow')
ax.set_ylim(0, 40)

ax.legend()

plt.grid(False)

plt.show()

# %% [markdown]
# **2. Scatter Ploting**

# %%
# Scatter Ploting
# Creating Fig,
fig, ax = plt.subplots(figsize=(15, 5))

ax.scatter(x, y,  label='Temperature',color='red')
ax.scatter(x, z, label='precipitation', color='yellow')
ax.scatter(x, w, label='wind speed', color='blue')

#label
ax.set_ylabel('Temperature,Precipitation,Wind Speed')
ax.set_xlabel('Date')
ax.set_title('Weather Data  Of KTM 2024')

# Stick label/Ticks Labels
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85)
ax.set_ylim(0, 40)

plt.legend()

plt.grid(False)

plt.show()

# %% [markdown]
# **3. Stem Ploting**

# %%
# Steam Ploting
# Creating Fig,
fig, ax = plt.subplots(figsize=(15, 5))

ax.stem(x, y,  label='Temperature', markerfmt='red') # This markerfmt for stem color
ax.stem(x, z, label='precipitation', markerfmt='yellow')
ax.stem(x, w, label='wind speed', markerfmt='blue')


#label
ax.set_ylabel('Temperature,Precipitation,Wind Speed')
ax.set_xlabel('Date')
ax.set_title('Weather Data  Of KTM 2024')

# Stick label/Ticks Labels
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85, color='yellow')
ax.set_ylim(0, 40)

plt.legend()

plt.grid(False)

plt.show()

# %%
# Stem Plot For only Wind Speed
# Creating Fig,
fig, ax = plt.subplots(figsize=(15, 5))

ax.stem(x, w, label='wind speed', markerfmt='blue') # Set marker color to blue

#label
ax.set_ylabel('Wind Speed')
ax.set_xlabel('Date')
ax.set_title('Weather Data  Of KTM 2024')

# Stick label/Ticks Labels
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85, color='yellow')
ax.set_ylim(0, 40)
plt.legend()

plt.grid(False)

plt.show()

# %% [markdown]
# **4. Bar Ploting**

# %%
# Bar Plot For All Three;[Temperature,Precipitation and Wind Speed]
# Creating Fig,
fig, ax = plt.subplots(figsize=(15, 5))

ax.bar(x, y,  label='Temperature', color='red')
ax.bar(x, z, label='precipitation', color='blue')
ax.bar(x, w, label='wind speed', color='yellow')

#lables
ax.set_ylabel('Temperature, Precipitation, Wind Speed')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Label
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85)
ax.set_ylim(0, 40)

plt.legend()

plt.grid(False)

plt.show()

# %%
# Bar Plot For Only Temperature
# Backgroung Style
plt.style.use('dark_background')
# Creating Fig,
fig, ax = plt.subplots(figsize=(15, 5))

ax.bar(x, y, label='Temperature', color='pink')

#label
ax.set_ylabel('Temperature')
ax.set_xlabel('Date')
ax.set_title('Weather Of Kathmandu 2024', color='violet')

# Sticks/Ticks Labels
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85)
ax.set_ylim(0, 40)
ax.set_facecolor('brown')

plt.legend()

plt.grid(False)

plt.show()

# %% [markdown]
# **5. Stack Ploting**

# %%
# Stacks Ploting For All Three[Temperature,Preciitation and Wind Speed]
# Creating Fig,
fig, ax = plt.subplots(figsize=(15, 5))

ax.stackplot(x, y, z, w, labels=['Temperature', 'Precipitation', 'Wind Speed'], colors=['red', 'yellow', 'blue'])

#label
ax.set_ylabel('Temperature, Precipitation, Wind Speed')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85)
ax.set_ylim(0, 45)

plt.legend()

plt.grid(False)

plt.show()

# %%
# Stack Plot For Temperature
# Creating Fig,
fig, ax = plt.subplots(figsize=(15, 5))

ax.stackplot(x, y, labels=['Temperature'], colors=['red'])

#label
ax.set_ylabel('Temperature')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

  # Sticks/Ticks Labels
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85)
ax.set_ylim(0, 40)

plt.legend()

plt.grid(False)

plt.show()

# %%
# Stack Ploting For Wind Speed
# Creating Fig,
fig, ax = plt.subplots(figsize=(15, 5))

ax.stackplot(x, w, labels=['Wind Speed'], colors=['blue'])

#label
ax.set_ylabel('Wind Speed')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85)
ax.set_ylim(0, 40)

plt.legend()

plt.grid(False)

plt.show()

# %%
# Stack Ploting For Preci[itation
# Creating Fig,
fig, ax = plt.subplots(figsize=(15, 5))

ax.stackplot(x, z, labels=['Precipitation'], colors=['yellow'])

#label
ax.set_ylabel('Precipitation')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85)
ax.set_ylim(0, 40)

plt.legend()

plt.grid(False)

plt.show()

# %% [markdown]
# **6. Stairs Ploting**

# %%
# Stairs Ploting For All Three
# Creating Fig,
fig, ax = plt.subplots(figsize=(15, 5))

ax.stairs(y, label='Temperature', color='red')
ax.stairs(z, label='Precipitation', color='blue')
ax.stairs(w, label='Wind Speed', color='yellow')

#label
ax.set_ylabel('Temperature, Precipitation, Wind Speed')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticklabels(x[::1], rotation=85)
ax.set_ylim(0, 40)

plt.legend()

plt.grid(False)

plt.show()
# Out:
# <ipython-input-197-ea363c482545>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x[::1], rotation=85)

# %%
# Stair Ploting For Temperature
# Creating Fig,
fig, ax = plt.subplots(figsize=(15, 5))

ax.stairs(y, label='Temperature', color='red')

#label
ax.set_ylabel('Temperature')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticklabels(x[::1], rotation=85)
ax.set_ylim(0, 40)

plt.legend()

plt.grid(False)

plt.show()
# Out:
# <ipython-input-201-675198022c08>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x[::1], rotation=85)

# %%
# Stair Ploting of Wind Speed
# Creating Fig,
fig, ax = plt.subplots(figsize=(15, 5))

ax.stairs(w, label='Wind Speed', color='yellow')

#label
ax.set_ylabel('Wind Speed')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticklabels(x[::1], rotation=85)
ax.set_ylim(0, 15)

plt.legend()

plt.grid(False)

plt.show()
# Out:
# <ipython-input-205-97e4ab7c598a>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x[::1], rotation=85)

# %% [markdown]
# **7. Fill Between Ploting**

# %%
# Fill Between ploting for all Three
# Creating fig,
fig, ax = plt.subplots(figsize=(15, 5))

ax.fill_between(x, y, z, label='Temperature and Precipitation', color='red')
ax.fill_between(x, y, w, label='Temperature and Wind Speed', color='yellow')

#label
ax.set_ylabel('Temperature, Precipitation, Wind Speed')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85)
ax.set_ylim(0, 40)

plt.legend()

plt.grid(False)

plt.show()

# %%
# Fill_between Ploting Of Temperature
# Creating Figure
fig, ax = plt.subplots(figsize=(15, 5))

ax.fill_between(x, y, label='Temperature', color='red')

#label
ax.set_ylabel('Temperature')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85)
ax.set_ylim(0, 40)

plt.legend()

plt.grid(False)

plt.show()

# %%
# Fill Between Ploting For Wind Speed
# Creating Figure For Graph Ploting
fig, ax = plt.subplots(figsize=(15, 5))

ax.fill_between(x, w, label='Wind Speed', color='yellow')

#label
ax.set_ylabel('Wind Speed')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85)
ax.set_ylim(0, 40)

plt.legend()

plt.grid(False)

plt.show()

# %% [markdown]
# **8. Hist Ploting**

# %%
# Hist Ploting For All three
# Creating Figure
fig, ax = plt.subplots(figsize=(15, 5))

ax.hist(y, label='Temperature', color='red')
ax.hist(z, label='Precipitation', color='yellow')
ax.hist(w, label='Wind Speed', color='blue')

#label
ax.set_ylabel('Temperature, Precipitation, Wind Speed')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticklabels(x, rotation=85)
ax.set_ylim(0, 30)

plt.legend()

plt.grid(False)

plt.show()
# Out:
# <ipython-input-216-e1556d521ae5>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=85)

# %%
# Hist Ploting For Temperature
# Creating figure
fig, ax = plt.subplots(figsize=(15, 5))

ax.hist(y, label='Temperature', color='red')

#label
ax.set_ylabel('Temperature')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticklabels(x, rotation=85)
ax.set_ylim(0, 30)

plt.legend()

plt.grid(False)

plt.show()
# Out:
# <ipython-input-217-e28331d5fca2>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=85)

# %%
# Hist Ploting For Precipitation
# Creating figure
fig, ax = plt.subplots(figsize=(15, 5))

ax.hist(z, label='Precipitation', color='yellow')

#label
ax.set_ylabel('Precipitation')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticklabels(x, rotation=85)
ax.set_ylim(0, 30)

plt.legend()

plt.grid(False)

plt.show()
# Out:
# <ipython-input-218-4e689a93b0b7>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=85)

# %%
# Hist Ploting For Wind speed
# Crating figure
fig, ax = plt.subplots(figsize=(15, 5))

ax.hist(w, label='Wind Speed', color='blue')

#label
ax.set_ylabel('Wind Speed')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticklabels(x, rotation=85)
ax.set_ylim(0,30)

plt.legend()

plt.grid(False)

plt.show()
# Out:
# <ipython-input-219-a032faa40f1b>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=85)

# %% [markdown]
# **9. Plot Diffrent Plots**

# %%
# Plots Diffrent Plots for  All Three
# Creating Figure
fig, ax = plt.subplots(figsize=(15, 5))

ax.plot(x, y, label='Temperature', color='red')
ax.plot(x, z, label='Precipitation', color='yellow')
ax.plot(x, w, label='Wind Speed', color='blue')

#label
ax.set_ylabel('Temperature, Precipitation, Wind Speed')
ax.set_xlabel('Date')
ax.set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax.set_xticks(x[::1])
ax.set_xticklabels(x[::1], rotation=85, fontsize=7)
ax.set_ylim(0, 40)

plt.legend()

plt.grid(False)

plt.show()

# %% [markdown]
# **10. Create One(2x2) Axes**

# %%
# Create one (2x2) Axes
# Creating Figure
fig, ax = plt.subplots(2, 2)
fig.set_size_inches(20, 10)

#Temperature
ax[0, 0].plot(x, y, label='Temperature', color='red')

#label
ax[0, 0].set_ylabel('Temperature')
ax[0, 0].set_xlabel('Date')
ax[0, 0].set_title('Temperature of Ktm 2024')

# Sticks/Ticks label
ax[0, 0].set_xticks(x[::1])
ax[0, 0].set_xticklabels(x[::1], rotation=90, fontsize=7, color='white')

#Precipitation
ax[0, 1].plot(x, z, label='Precipitation', color='yellow')

#label
ax[0, 1].set_ylabel('Precipitation')
ax[0, 1].set_xlabel('Date')
ax[0, 1].set_title('Precipitation of Ktm 2024')

# Sticks/Ticks Labels
ax[0, 1].set_xticks(x[::1])
ax[0, 1].set_xticklabels(x[::1], rotation=90, fontsize=7, color='yellow')

#wind speed
ax[1, 0].plot(x, w, label='Wind Speed', color='blue')

#label
ax[1, 0].set_ylabel('Wind Speed')
ax[1, 0].set_xlabel('Date')
ax[1, 0].set_title('Wind Speed of Ktm 2024')

# Sticks/Ticks Labels
ax[1, 0].set_xticks(x[::1])
ax[1, 0].set_xticklabels(x[::1], rotation=90, fontsize=7, color='white')

#All Three
ax[1, 1].plot(x, y, label='Temperature', color='red')
ax[1, 1].plot(x, z, label='Precipitation', color='yellow')
ax[1, 1].plot(x, w, label='Wind Speed', color='blue')

#label
ax[1, 1].set_ylabel('Temperature, Precipitation, Wind Speed')
ax[1, 1].set_xlabel('Date')
ax[1, 1].set_title('Weather Data of KTM 2024')

# Sticks/Ticks Labels
ax[1, 1].set_xticks(x[::1])
ax[1, 1].set_xticklabels(x[::1], rotation=90, fontsize=7, color='yellow')

plt.tight_layout()

plt.legend()

plt.grid(False)

plt.show()
